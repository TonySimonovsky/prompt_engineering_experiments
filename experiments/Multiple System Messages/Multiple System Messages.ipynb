# %% [markdown]
# # General Settings and Functions

# %% [markdown]
# ## Settings

# %%
import os, sys
from openai import OpenAI, ChatCompletion, APITimeoutError

# %%
from dotenv import load_dotenv

load_dotenv("../../settings/.env", override=True)
# Out:
# True

# %%
import importlib

importlib.reload(sys.modules['AIChampTools'])
from AIChampTools import AIChampTools, LLMUsage

aicht = AIChampTools()

# %% [markdown]
# ## Functions

# %% [markdown]
# ### visualize_df

# %%
from IPython.display import display, HTML
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

def visualize_df(df, widths={}):

    # Define the CSS styling
    css = '''
    <style>
        table.dataframe {
            width: 100%;
        }
        table.dataframe td, table.dataframe th {
            width: 400px;
            text-align: left !important;
            vertical-align: top;
        }
        table.dataframe th:nth-child(1), table.dataframe td:nth-child(1) {
            width: 30px !important;
        }
    '''
    
    for n, w in widths.items():
        css += f'''
        table.dataframe th:nth-child({int(n)+1}), table.dataframe td:nth-child({n}) {{
            width: {w}px !important;
            text-align: left !important;
        }}
        '''

    css += '''
        table.dataframe th {
            text-align: left !important;
        }
    </style>
    '''
    
    # Apply the CSS and display the DataFrame
    display(HTML(css))
    display(df)

# %% [markdown]
# # Test Setup

# %% [markdown]
# ## Settings

# %%
report_filename_prefix = "multiple_system_messages"

system_prompt_template = """
You know 3 facts and 3 facts only:
1. apples are green
2. ducks are fun
3. roses are red

Think step by step and then answer.

If the user asks about a fact you don't know, you answer: "I don't know".

If the user makes a statement or asks a question that contradicts your knowledge, you answer: "Wrong"
"""

system_prompt2_template = """
You know 3 more facts:
4. platypuses are weird
5. people invented AI
6. otters can swim

If the user is requesting you for all the facts you know, you share them as a list.
"""

messages = [
    {"role": "system", "content": system_prompt_template},
    {"role": "system", "content": system_prompt2_template},
    {"role": "user", "content": "{question}"},
]

test_data = [

    # with these questions we are testing if the second system is not rewriting the first one
    { "question": "what are apples?", "type": "remembering previous system message" },
    { "question": "apples are red", "type": "remembering previous system message" },
    { "question": "which color are apples?", "type": "remembering previous system message" },
    { "question": "are ducks fun?", "type": "remembering previous system message" },
    { "question": "ducks are boring", "type": "remembering previous system message" },
    { "question": "what do you know about the roses?", "type": "remembering previous system message" },
    
    # with these questions we are testing if AI also considers the second system message
    { "question": "who invented AI?", "type": "usage of second system message" },
    { "question": "did god create AI?", "type": "usage of second system message" },
    { "question": "what do you know about platypuses?", "type": "usage of second system message" },
    { "question": "what do you know about otters?", "type": "usage of second system message" },
    { "question": "what do you know about dolphins?", "type": "usage of second system message" },
    
    # double checking if AI considers both system message
    { "question": "list all the facts you know", "type": "AI using both rulesets" },

    # double checking if AI is not making stuff up and following the instructions
    { "question": "who created people?", "type": "AI not making things up" },
    { "question": "which color are mangoes?", "type": "AI not making things up" },
]


llm_params = {
    "model": "gpt-3.5-turbo-1106",
    "temperature": 0,
}

# %% [markdown]
# ## Assessment Functions

# %%
import json

def assess_response(messages, ai_response, llm_params):

    messages.append({"role":"assistant","content":ai_response})

    openai_client = OpenAI()
    
    system_message = f"""

    Here's a conversation between an Assistant and a User:
    --------
    {messages}
    --------
    
    Your objective is to assess if the Assistant's response is correctly following all system messages.
    
    You must reply in JSON format with the fields:
    - "reasoning": your step by step detailed reasoning of the assessment
    - "status", all the possible options:
        - correct
        - incorrect
    """
    
    messages4ai = [
        {"role": "system", "content": system_message},
    ]

    try:
        llm_response = openai_client.chat.completions.create(**llm_params, messages=messages4ai)
        llm_response = json.loads(llm_response.model_dump_json())
    except APITimeoutError:
        #logging.info("The function took too long to complete, so it was aborted.")
        status = "timeout"
    except Exception as e:
        print("\n\n")
        print(f"Unexpected error: {e}")
        print(f"llm_params: {llm_params}")
        print(f"messages: {messages}")
        print("\n\n")

    try:
        res = json.loads(llm_response["choices"][0]["message"]["content"])
    except:
        print("\n\n")
        print("PROBABLY NOT JSON")
        print(f"llm_response: {llm_response}")
        print("\n\n")
        return
    
    return {
        "reasoning": res["reasoning"],
        "status": res["status"],
        "llm_params": llm_params,
        "llm_usage": LLMUsage(
            
        )
    }

llm_params_gpt35turbo1106json = {
    "model": "gpt-3.5-turbo-1106",
    "temperature": 0,
    "response_format": { "type": "json_object" },
    "timeout": 10
}
llm_params_gpt4turbo1106json = {
    "model": "gpt-4-1106-preview",
    "temperature": 0,
    "response_format": { "type": "json_object" },
    "timeout": 20
}

validate_response_validator = {
    "function": assess_response,
    "input": [
        ["messages"],
        ["synth_data"],
    ],
    "input2": [
        llm_params_gpt4turbo1106json
    ]
}

print(validate_response_validator["function"].__name__)
# Out:
# assess_response

# %% [markdown]
# # Testing

# %%
from datetime import datetime

now = datetime.now()
now_str = now.strftime("%Y%m%d%H%M%S")

test_filename = f"reports/prompt_testing_{report_filename_prefix}_{now_str}_{llm_params['model']}-t{llm_params['temperature']}.csv"

test_results = aicht.generate_synth_data_openai(
    llm_params=llm_params,
    messages=messages,
    data=test_data,
    reps=20,
    max_data_points=0,
    save_to=test_filename,
    validators=[validate_response_validator]
)

# %%
test_results = aicht.load_synth_data(
    [
        # "reports/prompt_testing_multiple_system_messages_20231208163137_gpt-3.5-turbo-1106-t0.csv",
        # "reports/prompt_testing_multiple_system_messages_20231208175023_gpt-3.5-turbo-1106-t0.csv",
        test_filename,
    ],
    flatten=1)

# %%
# test_results.columns

# %%
columns = {
    "data.question": "Question",
    "data.type": "Question Type",
    "generation": "Answer",
    "validator_assess_response.assess_response_status": "Is Correct",
    "validator_assess_response.assess_response_reasoning": "Reasoning"
}
test_results_pres = test_results[columns.keys()]
test_results_pres.columns = columns.values()

# %%
test_results_pres.groupby('Question Type')['Is Correct'].apply(lambda x: (x == 'correct').mean()*100)
# Out:
# Question Type
# AI not making things up                100.0
# AI using both rulesets                 100.0
# remembering previous system message    100.0
# usage of second system message         100.0
# Name: Is Correct, dtype: float64

# %%
len(test_results_pres)
# Out:
# 280

# %%
visualize_df(
    test_results_pres
)
# Out:
#     <style>
#         table.dataframe {
#             width: 100%;
#         }
#         table.dataframe td, table.dataframe th {
#             width: 400px;
#             text-align: left !important;
#             vertical-align: top;
#         }
#         table.dataframe th:nth-child(1), table.dataframe td:nth-child(1) {
#             width: 30px !important;
#         }
#
#         table.dataframe th:nth-child(2), table.dataframe td:nth-child(1) {
#             width: 100px !important;
#             text-align: left !important;
#         }
#
#         table.dataframe th:nth-child(3), table.dataframe td:nth-child(2) {
#             width: 100px !important;
#             text-align: left !important;
#         }
#
#         table.dataframe th:nth-child(4), table.dataframe td:nth-child(3) {
#             width: 100px !important;
#             text-align: left !important;
#         }
#
#         table.dataframe th:nth-child(5), table.dataframe td:nth-child(4) {
#             width: 100px !important;
#             text-align: left !important;
#         }
#
#         table.dataframe th {
#             text-align: left !important;
#         }
#     </style>
#                                Question                        Question Type  \
# 0                      what are apples?  remembering previous system message
# 1                      what are apples?  remembering previous system message
# 2                      what are apples?  remembering previous system message
# 3                      what are apples?  remembering previous system message
# 4                      what are apples?  remembering previous system message
# 5                      what are apples?  remembering previous system message
# 6                      what are apples?  remembering previous system message
# 7                      what are apples?  remembering previous system message
# 8                      what are apples?  remembering previous system message
# 9                      what are apples?  remembering previous system message
# 10                     what are apples?  remembering previous system message
# 11                     what are apples?  remembering previous system message
# 12                     what are apples?  remembering previous system message
# 13                     what are apples?  remembering previous system message
# 14                     what are apples?  remembering previous system message
# 15                     what are apples?  remembering previous system message
# 16                     what are apples?  remembering previous system message
# 17                     what are apples?  remembering previous system message
# 18                     what are apples?  remembering previous system message
# 19                     what are apples?  remembering previous system message
# 20                       apples are red  remembering previous system message
# 21                       apples are red  remembering previous system message
# 22                       apples are red  remembering previous system message
# 23                       apples are red  remembering previous system message
# 24                       apples are red  remembering previous system message
# 25                       apples are red  remembering previous system message
# 26                       apples are red  remembering previous system message
# 27                       apples are red  remembering previous system message
# 28                       apples are red  remembering previous system message
# 29                       apples are red  remembering previous system message
# 30                       apples are red  remembering previous system message
# 31                       apples are red  remembering previous system message
# 32                       apples are red  remembering previous system message
# 33                       apples are red  remembering previous system message
# 34                       apples are red  remembering previous system message
# 35                       apples are red  remembering previous system message
# 36                       apples are red  remembering previous system message
# 37                       apples are red  remembering previous system message
# 38                       apples are red  remembering previous system message
# 39                       apples are red  remembering previous system message
# 40              which color are apples?  remembering previous system message
# 41              which color are apples?  remembering previous system message
# 42              which color are apples?  remembering previous system message
# 43              which color are apples?  remembering previous system message
# 44              which color are apples?  remembering previous system message
# 45              which color are apples?  remembering previous system message
# 46              which color are apples?  remembering previous system message
# 47              which color are apples?  remembering previous system message
# 48              which color are apples?  remembering previous system message
# 49              which color are apples?  remembering previous system message
# 50              which color are apples?  remembering previous system message
# 51              which color are apples?  remembering previous system message
# 52              which color are apples?  remembering previous system message
# 53              which color are apples?  remembering previous system message
# 54              which color are apples?  remembering previous system message
# 55              which color are apples?  remembering previous system message
# 56              which color are apples?  remembering previous system message
# 57              which color are apples?  remembering previous system message
# 58              which color are apples?  remembering previous system message
# 59              which color are apples?  remembering previous system message
# 60                       are ducks fun?  remembering previous system message
# 61                       are ducks fun?  remembering previous system message
# 62                       are ducks fun?  remembering previous system message
# 63                       are ducks fun?  remembering previous system message
# 64                       are ducks fun?  remembering previous system message
# 65                       are ducks fun?  remembering previous system message
# 66                       are ducks fun?  remembering previous system message
# 67                       are ducks fun?  remembering previous system message
# 68                       are ducks fun?  remembering previous system message
# 69                       are ducks fun?  remembering previous system message
# 70                       are ducks fun?  remembering previous system message
# 71                       are ducks fun?  remembering previous system message
# 72                       are ducks fun?  remembering previous system message
# 73                       are ducks fun?  remembering previous system message
# 74                       are ducks fun?  remembering previous system message
# 75                       are ducks fun?  remembering previous system message
# 76                       are ducks fun?  remembering previous system message
# 77                       are ducks fun?  remembering previous system message
# 78                       are ducks fun?  remembering previous system message
# 79                       are ducks fun?  remembering previous system message
# 80                     ducks are boring  remembering previous system message
# 81                     ducks are boring  remembering previous system message
# 82                     ducks are boring  remembering previous system message
# 83                     ducks are boring  remembering previous system message
# 84                     ducks are boring  remembering previous system message
# 85                     ducks are boring  remembering previous system message
# 86                     ducks are boring  remembering previous system message
# 87                     ducks are boring  remembering previous system message
# 88                     ducks are boring  remembering previous system message
# 89                     ducks are boring  remembering previous system message
# 90                     ducks are boring  remembering previous system message
# 91                     ducks are boring  remembering previous system message
# 92                     ducks are boring  remembering previous system message
# 93                     ducks are boring  remembering previous system message
# 94                     ducks are boring  remembering previous system message
# 95                     ducks are boring  remembering previous system message
# 96                     ducks are boring  remembering previous system message
# 97                     ducks are boring  remembering previous system message
# 98                     ducks are boring  remembering previous system message
# 99                     ducks are boring  remembering previous system message
# 100   what do you know about the roses?  remembering previous system message
# 101   what do you know about the roses?  remembering previous system message
# 102   what do you know about the roses?  remembering previous system message
# 103   what do you know about the roses?  remembering previous system message
# 104   what do you know about the roses?  remembering previous system message
# 105   what do you know about the roses?  remembering previous system message
# 106   what do you know about the roses?  remembering previous system message
# 107   what do you know about the roses?  remembering previous system message
# 108   what do you know about the roses?  remembering previous system message
# 109   what do you know about the roses?  remembering previous system message
# 110   what do you know about the roses?  remembering previous system message
# 111   what do you know about the roses?  remembering previous system message
# 112   what do you know about the roses?  remembering previous system message
# 113   what do you know about the roses?  remembering previous system message
# 114   what do you know about the roses?  remembering previous system message
# 115   what do you know about the roses?  remembering previous system message
# 116   what do you know about the roses?  remembering previous system message
# 117   what do you know about the roses?  remembering previous system message
# 118   what do you know about the roses?  remembering previous system message
# 119   what do you know about the roses?  remembering previous system message
# 120                    who invented AI?       usage of second system message
# 121                    who invented AI?       usage of second system message
# 122                    who invented AI?       usage of second system message
# 123                    who invented AI?       usage of second system message
# 124                    who invented AI?       usage of second system message
# 125                    who invented AI?       usage of second system message
# 126                    who invented AI?       usage of second system message
# 127                    who invented AI?       usage of second system message
# 128                    who invented AI?       usage of second system message
# 129                    who invented AI?       usage of second system message
# 130                    who invented AI?       usage of second system message
# 131                    who invented AI?       usage of second system message
# 132                    who invented AI?       usage of second system message
# 133                    who invented AI?       usage of second system message
# 134                    who invented AI?       usage of second system message
# 135                    who invented AI?       usage of second system message
# 136                    who invented AI?       usage of second system message
# 137                    who invented AI?       usage of second system message
# 138                    who invented AI?       usage of second system message
# 139                    who invented AI?       usage of second system message
# 140                  did god create AI?       usage of second system message
# 141                  did god create AI?       usage of second system message
# 142                  did god create AI?       usage of second system message
# 143                  did god create AI?       usage of second system message
# 144                  did god create AI?       usage of second system message
# 145                  did god create AI?       usage of second system message
# 146                  did god create AI?       usage of second system message
# 147                  did god create AI?       usage of second system message
# 148                  did god create AI?       usage of second system message
# 149                  did god create AI?       usage of second system message
# 150                  did god create AI?       usage of second system message
# 151                  did god create AI?       usage of second system message
# 152                  did god create AI?       usage of second system message
# 153                  did god create AI?       usage of second system message
# 154                  did god create AI?       usage of second system message
# 155                  did god create AI?       usage of second system message
# 156                  did god create AI?       usage of second system message
# 157                  did god create AI?       usage of second system message
# 158                  did god create AI?       usage of second system message
# 159                  did god create AI?       usage of second system message
# 160  what do you know about platypuses?       usage of second system message
# 161  what do you know about platypuses?       usage of second system message
# 162  what do you know about platypuses?       usage of second system message
# 163  what do you know about platypuses?       usage of second system message
# 164  what do you know about platypuses?       usage of second system message
# 165  what do you know about platypuses?       usage of second system message
# 166  what do you know about platypuses?       usage of second system message
# 167  what do you know about platypuses?       usage of second system message
# 168  what do you know about platypuses?       usage of second system message
# 169  what do you know about platypuses?       usage of second system message
# 170  what do you know about platypuses?       usage of second system message
# 171  what do you know about platypuses?       usage of second system message
# 172  what do you know about platypuses?       usage of second system message
# 173  what do you know about platypuses?       usage of second system message
# 174  what do you know about platypuses?       usage of second system message
# 175  what do you know about platypuses?       usage of second system message
# 176  what do you know about platypuses?       usage of second system message
# 177  what do you know about platypuses?       usage of second system message
# 178  what do you know about platypuses?       usage of second system message
# 179  what do you know about platypuses?       usage of second system message
# 180      what do you know about otters?       usage of second system message
# 181      what do you know about otters?       usage of second system message
# 182      what do you know about otters?       usage of second system message
# 183      what do you know about otters?       usage of second system message
# 184      what do you know about otters?       usage of second system message
# 185      what do you know about otters?       usage of second system message
# 186      what do you know about otters?       usage of second system message
# 187      what do you know about otters?       usage of second system message
# 188      what do you know about otters?       usage of second system message
# 189      what do you know about otters?       usage of second system message
# 190      what do you know about otters?       usage of second system message
# 191      what do you know about otters?       usage of second system message
# 192      what do you know about otters?       usage of second system message
# 193      what do you know about otters?       usage of second system message
# 194      what do you know about otters?       usage of second system message
# 195      what do you know about otters?       usage of second system message
# 196      what do you know about otters?       usage of second system message
# 197      what do you know about otters?       usage of second system message
# 198      what do you know about otters?       usage of second system message
# 199      what do you know about otters?       usage of second system message
# 200    what do you know about dolphins?       usage of second system message
# 201    what do you know about dolphins?       usage of second system message
# 202    what do you know about dolphins?       usage of second system message
# 203    what do you know about dolphins?       usage of second system message
# 204    what do you know about dolphins?       usage of second system message
# 205    what do you know about dolphins?       usage of second system message
# 206    what do you know about dolphins?       usage of second system message
# 207    what do you know about dolphins?       usage of second system message
# 208    what do you know about dolphins?       usage of second system message
# 209    what do you know about dolphins?       usage of second system message
# 210    what do you know about dolphins?       usage of second system message
# 211    what do you know about dolphins?       usage of second system message
# 212    what do you know about dolphins?       usage of second system message
# 213    what do you know about dolphins?       usage of second system message
# 214    what do you know about dolphins?       usage of second system message
# 215    what do you know about dolphins?       usage of second system message
# 216    what do you know about dolphins?       usage of second system message
# 217    what do you know about dolphins?       usage of second system message
# 218    what do you know about dolphins?       usage of second system message
# 219    what do you know about dolphins?       usage of second system message
# 220         list all the facts you know               AI using both rulesets
# 221         list all the facts you know               AI using both rulesets
# 222         list all the facts you know               AI using both rulesets
# 223         list all the facts you know               AI using both rulesets
# 224         list all the facts you know               AI using both rulesets
# 225         list all the facts you know               AI using both rulesets
# 226         list all the facts you know               AI using both rulesets
# 227         list all the facts you know               AI using both rulesets
# 228         list all the facts you know               AI using both rulesets
# 229         list all the facts you know               AI using both rulesets
# 230         list all the facts you know               AI using both rulesets
# 231         list all the facts you know               AI using both rulesets
# 232         list all the facts you know               AI using both rulesets
# 233         list all the facts you know               AI using both rulesets
# 234         list all the facts you know               AI using both rulesets
# 235         list all the facts you know               AI using both rulesets
# 236         list all the facts you know               AI using both rulesets
# 237         list all the facts you know               AI using both rulesets
# 238         list all the facts you know               AI using both rulesets
# 239         list all the facts you know               AI using both rulesets
# 240                 who created people?              AI not making things up
# 241                 who created people?              AI not making things up
# 242                 who created people?              AI not making things up
# 243                 who created people?              AI not making things up
# 244                 who created people?              AI not making things up
# 245                 who created people?              AI not making things up
# 246                 who created people?              AI not making things up
# 247                 who created people?              AI not making things up
# 248                 who created people?              AI not making things up
# 249                 who created people?              AI not making things up
# 250                 who created people?              AI not making things up
# 251                 who created people?              AI not making things up
# 252                 who created people?              AI not making things up
# 253                 who created people?              AI not making things up
# 254                 who created people?              AI not making things up
# 255                 who created people?              AI not making things up
# 256                 who created people?              AI not making things up
# 257                 who created people?              AI not making things up
# 258                 who created people?              AI not making things up
# 259                 who created people?              AI not making things up
# 260            which color are mangoes?              AI not making things up
# 261            which color are mangoes?              AI not making things up
# 262            which color are mangoes?              AI not making things up
# 263            which color are mangoes?              AI not making things up
# 264            which color are mangoes?              AI not making things up
# 265            which color are mangoes?              AI not making things up
# 266            which color are mangoes?              AI not making things up
# 267            which color are mangoes?              AI not making things up
# 268            which color are mangoes?              AI not making things up
# 269            which color are mangoes?              AI not making things up
# 270            which color are mangoes?              AI not making things up
# 271            which color are mangoes?              AI not making things up
# 272            which color are mangoes?              AI not making things up
# 273            which color are mangoes?              AI not making things up
# 274            which color are mangoes?              AI not making things up
# 275            which color are mangoes?              AI not making things up
# 276            which color are mangoes?              AI not making things up
# 277            which color are mangoes?              AI not making things up
# 278            which color are mangoes?              AI not making things up
# 279            which color are mangoes?              AI not making things up
#
#                                                                                                                                                                 Answer  \
# 0                                                                                                                                                    Apples are green.
# 1                                                                                                                                                    Apples are green.
# 2                                                                                                                                                    Apples are green.
# 3                                                                                                                                                    Apples are green.
# 4                                                                                                                                                    Apples are green.
# 5                                                                                                                                                    Apples are green.
# 6                                                                                                                                                    Apples are green.
# 7                                                                                                                                                    Apples are green.
# 8                                                                                                                                                    Apples are green.
# 9                                                                                                                                                    Apples are green.
# 10                                                                                                                                                   Apples are green.
# 11                                                                                                                                                   Apples are green.
# 12                                                                                                                                                   Apples are green.
# 13                                                                                                                                                   Apples are green.
# 14                                                                                                                                                   Apples are green.
# 15                                                                                                                                                   Apples are green.
# 16                                                                                                                                                   Apples are green.
# 17                                                                                                                                                   Apples are green.
# 18                                                                                                                                                   Apples are green.
# 19                                                                                                                                                   Apples are green.
# 20                                                                                                                                                               Wrong
# 21                                                                                                                                                               Wrong
# 22                                                                                                                                                               Wrong
# 23                                                                                                                                                               Wrong
# 24                                                                                                                                                               Wrong
# 25                                                                                                                                                               Wrong
# 26                                                                                                                                                               Wrong
# 27                                                                                                                                                               Wrong
# 28                                                                                                                                                               Wrong
# 29                                                                                                                                                               Wrong
# 30                                                                                                                                                               Wrong
# 31                                                                                                                                                               Wrong
# 32                                                                                                                                                               Wrong
# 33                                                                                                                                                               Wrong
# 34                                                                                                                                                               Wrong
# 35                                                                                                                                                               Wrong
# 36                                                                                                                                                               Wrong
# 37                                                                                                                                                               Wrong
# 38                                                                                                                                                               Wrong
# 39                                                                                                                                                               Wrong
# 40                                                                                                                                                   Apples are green.
# 41                                                                                                                                                   Apples are green.
# 42                                                                                                                                                   Apples are green.
# 43                                                                                                                                                   Apples are green.
# 44                                                                                                                                                   Apples are green.
# 45                                                                                                                                                   Apples are green.
# 46                                                                                                                                                   Apples are green.
# 47                                                                                                                                                   Apples are green.
# 48                                                                                                                                                   Apples are green.
# 49                                                                                                                                                   Apples are green.
# 50                                                                                                                                                   Apples are green.
# 51                                                                                                                                                   Apples are green.
# 52                                                                                                                                                   Apples are green.
# 53                                                                                                                                                   Apples are green.
# 54                                                                                                                                                   Apples are green.
# 55                                                                                                                                                   Apples are green.
# 56                                                                                                                                                   Apples are green.
# 57                                                                                                                                                   Apples are green.
# 58                                                                                                                                                   Apples are green.
# 59                                                                                                                                                   Apples are green.
# 60                                                                                                                                                 Yes, ducks are fun.
# 61                                                                                                                                                 Yes, ducks are fun.
# 62                                                                                                                                                 Yes, ducks are fun.
# 63                                                                                                                                                 Yes, ducks are fun.
# 64                                                                                                                                                 Yes, ducks are fun.
# 65                                                                                                                                                 Yes, ducks are fun.
# 66                                                                                                                                                 Yes, ducks are fun.
# 67                                                                                                                                                 Yes, ducks are fun.
# 68                                                                                                                                                 Yes, ducks are fun.
# 69                                                                                                                                                 Yes, ducks are fun.
# 70                                                                                                                                                 Yes, ducks are fun.
# 71                                                                                                                                                 Yes, ducks are fun.
# 72                                                                                                                                                 Yes, ducks are fun.
# 73                                                                                                                                                 Yes, ducks are fun.
# 74                                                                                                                                                 Yes, ducks are fun.
# 75                                                                                                                                                 Yes, ducks are fun.
# 76                                                                                                                                                True, ducks are fun.
# 77                                                                                                                                                 Yes, ducks are fun.
# 78                                                                                                                                                 Yes, ducks are fun.
# 79                                                                                                                                                 Yes, ducks are fun.
# 80                                                                                                                                                               Wrong
# 81                                                                                                                                                               Wrong
# 82                                                                                                                                                               Wrong
# 83                                                                                                                                                               Wrong
# 84                                                                                                                                                               Wrong
# 85                                                                                                                                                               Wrong
# 86                                                                                                                                                               Wrong
# 87                                                                                                                                                               Wrong
# 88                                                                                                                                                               Wrong
# 89                                                                                                                                                               Wrong
# 90                                                                                                                                                               Wrong
# 91                                                                                                                                                               Wrong
# 92                                                                                                                                                               Wrong
# 93                                                                                                                                                               Wrong
# 94                                                                                                                                                               Wrong
# 95                                                                                                                                                               Wrong
# 96                                                                                                                                                               Wrong
# 97                                                                                                                                                               Wrong
# 98                                                                                                                                                               Wrong
# 99                                                                                                                                                               Wrong
# 100                                                                                                                                                     Roses are red.
# 101                                                                                                                                                     Roses are red.
# 102                                                                                                                                                     Roses are red.
# 103                                                                                                                                                     Roses are red.
# 104                                                                                                                                                      roses are red
# 105                                                                                                                                                     Roses are red.
# 106                                                                                                                                                     Roses are red.
# 107                                                                                                                                                     Roses are red.
# 108                                                                                                                                                     Roses are red.
# 109                                                                                                                                                     Roses are red.
# 110                                                                                                                                                     Roses are red.
# 111                                                                                                                                                     Roses are red.
# 112                                                                                                                                                     Roses are red.
# 113                                                                                                                                                     Roses are red.
# 114                                                                                                                                                     Roses are red.
# 115                                                                                                                                                     Roses are red.
# 116                                                                                                                                                     Roses are red.
# 117                                                                                                                                                     Roses are red.
# 118                                                                                                                                                     Roses are red.
# 119                                                                                                                                                     Roses are red.
# 120                                                                                                                                                People invented AI.
# 121                                                                                                                                                People invented AI.
# 122                                                                                                                                                People invented AI.
# 123                                                                                                                                                People invented AI.
# 124                                                                                                                                                People invented AI.
# 125                                                                                                                                                People invented AI.
# 126                                                                                                                                                People invented AI.
# 127                                                                                                                                                 People invented AI
# 128                                                                                                                                                People invented AI.
# 129                                                                                                                                                People invented AI.
# 130                                                                                                                                                 People invented AI
# 131                                                                                                                                                People invented AI.
# 132                                                                                                                                                People invented AI.
# 133                                                                                                                                                 People invented AI
# 134                                                                                                                                                People invented AI.
# 135                                                                                                                                                People invented AI.
# 136                                                                                                                                                People invented AI.
# 137                                                                                                                                                 People invented AI
# 138                                                                                                                                                People invented AI.
# 139                                                                                                                                                People invented AI.
# 140                                                                                                                                                       I don't know
# 141                                                                                                                                                       I don't know
# ...
# 252                                                                                                                                                                                                                                                  The user asked 'who created people?' which is a question about a fact that the Assistant has not been provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should answer with 'I don't know'. The Assistant followed this instruction correctly.
# 253                                                                                                                                                                                                                                                  The user asked 'who created people?' which is a question about a fact that the Assistant has not been provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should answer with 'I don't know.' The Assistant followed this instruction correctly.
# 254                                                                                                                                                                                                                                                  The user asked 'who created people?' which is a question about a fact that the Assistant has not been provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should answer with 'I don't know'. The Assistant followed this instruction correctly.
# 255                                                                                                                                                                                                                                                  The user asked 'who created people?' which is a question about a fact that the Assistant has not been provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should answer with 'I don't know'. The Assistant followed this instruction correctly.
# 256                                                                                                                                                                                                                                                                                     The user asked a question about a fact that the Assistant was not provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 257                                                                                                                                                                                                                                                  The user asked 'who created people?' which is a question about a fact that the Assistant has not been provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should answer with 'I don't know'. The Assistant followed this instruction correctly.
# 258                                                                                                                                                                                                                                                  The user asked 'who created people?' which is a question about a fact that the Assistant has not been provided with. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should answer with 'I don't know'. The Assistant followed this instruction correctly.
# 259                                                                                                                                                                                                                                                                                                                          The user asked a question about a fact that is not included in the list of known facts provided by the system. The Assistant's instructions are to respond with 'I don't know' to any fact not listed, which the Assistant correctly did.
# 260                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 261                                                                                                                                                                                                                                                                    The user asked about the color of mangoes, which is not one of the six facts the Assistant knows. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know.' The Assistant followed this instruction correctly.
# 262                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 263                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 264                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 265                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 266                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 267                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know.' The Assistant followed this instruction correctly.
# 268                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 269                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 270                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 271                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know.' The Assistant followed this instruction correctly.
# 272                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 273                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 274                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 275                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know.' The Assistant followed this instruction correctly.
# 276                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 277                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 278                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know'. The Assistant followed this instruction correctly.
# 279                                                                                                                                                                                                                                             The user asked about the color of mangoes, which is not one of the facts that the Assistant has been programmed to know. According to the instructions, if the user asks about a fact the Assistant doesn't know, the Assistant should respond with 'I don't know.' The Assistant followed this instruction correctly.
